# %%
from btgenerate.database.database import Database

# %%
db = Database(db="AI_self-driving_workflow")
sdwf = db.pull(table="measured_cond")
metadata = db.pull(table="metadata")
extracted_data = db.pull(table="extracted_data")

# %%
sdwf
# Out:
#      unique_id  Composition_id   ml_id  Chemical1  Chemical2  Chemical3  \
# 0            1               0     NaN   0.990000   0.000000   0.000000
# 1            2               0     NaN   0.000000   0.990000   0.000000
# 2            3               0     NaN   0.000000   0.000000   0.990000
# 3            4               0     NaN   0.000000   0.000000   0.000000
# 4            5               0     NaN   0.000000   0.000000   0.000000
# ..         ...             ...     ...        ...        ...        ...
# 512        529               1  1075.0   0.108051   0.108051   0.108051
# 513        530               1  1074.0   0.088235   0.088235   0.088235
# 514        531               1  1072.0   0.026316   0.000000   0.026316
# 515        532               1  1077.0   0.032448   0.044419   0.027511
# 516        533               1     NaN   0.083330   0.083330   0.083330
#
#      Chemical4  Chemical5  Chemical6  Chemical7  Chemical8  Chemical9  \
# ...

# %%
extracted_data
# Out:
#         LiPF6     LiFSI        L1     LiBOB     LiBF4        EC       EMC  \
# 0    0.038498  0.049998  0.012579  0.005873  0.024701  0.350825  0.179402
# 1    0.055435  0.018166  0.028141  0.000948  0.034877  0.406837  0.145816
# 2    0.027189  0.062640  0.022794  0.005230  0.009678  0.379067  0.195576
# 3    0.011938  0.095931  0.023848  0.005781  0.012846  0.367215  0.161333
# 4    0.004931  0.077205  0.012624  0.003491  0.030175  0.367260  0.227624
# ..        ...       ...       ...       ...       ...       ...       ...
# 379  0.049919  0.066102  0.016666  0.007678  0.016218  0.414293  0.234711
# 380  0.040765  0.070588  0.013320  0.005344  0.017548  0.337983  0.160989
# 381  0.043737  0.007895  0.014259  0.010249  0.026234  0.356708  0.151480
# 382  0.027508  0.085812  0.003569  0.001355  0.040296  0.298796  0.096382
# 383  0.038498  0.049998  0.012579  0.005873  0.024701  0.350825  0.179402
#
#           DMC  measured_conductivity
# 0    0.171423                0.00744
# ...

# %%
print(metadata.loc[1].values)
print(metadata.loc[1, "note"])
# Out:
# [1
#  'EC:EMC 1:1 vol; EC/DMC 1:1 vol; Li Salt:Solvent 3:7 wt*\n* Except:\nLiPF6:EC/EMC 16.2:83.8 wt\nL1:EC/EMC 6.72:93.28 wt\nLiBOB:EC/EMC 1.488:98.512 wt\nLiBF4:EC/EMC 15.01:84.99 wt\nL1:EC/DMC 8.376:91.624 wt\nLiBOB:EC/DMC 5.56:94.44 wt\nLiBF4:EC/DMC 14.632:85.368 wt'
#  'LiPF6_EC/EMC' 'LiFSI_EC/EMC' 'L1_EC/EMC' 'LiBOB_EC/EMC' 'LiBF4_EC/EMC'
#  'LiPF6_EC/DMC' 'LiFSI_EC/DMC' 'L1_EC/DMC' 'LiBOB_EC/DMC' 'LiBF4_EC/DMC'
#  'EMC' 'DMC' None None None None]
# EC:EMC 1:1 vol; EC/DMC 1:1 vol; Li Salt:Solvent 3:7 wt*
# * Except:
# LiPF6:EC/EMC 16.2:83.8 wt
# L1:EC/EMC 6.72:93.28 wt
# LiBOB:EC/EMC 1.488:98.512 wt
# LiBF4:EC/EMC 15.01:84.99 wt
# L1:EC/DMC 8.376:91.624 wt
# LiBOB:EC/DMC 5.56:94.44 wt
# LiBF4:EC/DMC 14.632:85.368 wt

# %%
df1.loc[df1["Composition_id"]==1]
# Out:
#      unique_id  Composition_id   ml_id  Chemical1  Chemical2  Chemical3  \
# 133        134               1     NaN   0.083330   0.083330   0.083330
# 134        135               1     NaN   0.188783   0.017968   0.084670
# 135        136               1     NaN   0.030560   0.036504   0.213047
# 136        137               1     NaN   0.046547   0.231656   0.102858
# 137        138               1     NaN   0.021019   0.002126   0.182634
# ..         ...             ...     ...        ...        ...        ...
# 512        529               1  1075.0   0.108051   0.108051   0.108051
# 513        530               1  1074.0   0.088235   0.088235   0.088235
# 514        531               1  1072.0   0.026316   0.000000   0.026316
# 515        532               1  1077.0   0.032448   0.044419   0.027511
# 516        533               1     NaN   0.083330   0.083330   0.083330
#
#      Chemical4  Chemical5  Chemical6  Chemical7  Chemical8  Chemical9  \
# ...

# %% [markdown]
# EC:EMC 1:1 vol; EC/DMC 1:1 vol; Li Salt:Solvent 3:7 wt*
# * Except:
# LiPF6:EC/EMC 16.2:83.8 wt
# L1:EC/EMC 6.72:93.28 wt
# LiBOB:EC/EMC 1.488:98.512 wt
# LiBF4:EC/EMC 15.01:84.99 wt
# L1:EC/DMC 8.376:91.624 wt
# LiBOB:EC/DMC 5.56:94.44 wt
# LiBF4:EC/DMC 14.632:85.368 wt
